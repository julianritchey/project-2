# %%
from GRIDtrade import grid_trading_strategy

# Example usage
symbol = 'TSLA'
start_date = '2022-01-15'
end_date = '2023-05-15'
test_start_date = '2023-01-15'
test_end_date = '2023-05-15'
initial_cash = 1000000
initial_quantity = 1000
quantity =50
percentage_change = 0.03
max_grid_count = 20

trade_records = grid_trading_strategy(symbol, start_date, end_date, test_start_date, test_end_date, initial_cash, initial_quantity, quantity, percentage_change, max_grid_count)
# Out:
# [*********************100%***********************]  1 of 1 completed
# /Users/vickygao/Desktop/ML/project_2/GRIDtrade.py:26: FutureWarning: Passing method to DatetimeIndex.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   nearest_index = test_df.index.get_loc(test_start_date, method='nearest')
