# %%
from GRIDtrade_simple import grid_trading_strategy

# Example usage
symbol = 'TSLA'
test_start_date = '2023-01-15'
test_end_date = '2023-05-15'

trade_records = grid_trading_strategy(symbol, test_start_date, test_end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed
