# %%
from os import environ as env
from dotenv import find_dotenv, load_dotenv
from questrade_api import Questrade

# %%
ENV_FILE = find_dotenv()
if ENV_FILE:
    load_dotenv(ENV_FILE)
    
qt_refresh_token = env.get('QUESTRADE_REFRESH_TOKEN')
print(qt_refresh_token)
# Out:
# mSUDSnmDVzee4Ci2sFWQd_SXROyFh6qh0

# %%
qt = Questrade()

# %%
qt.time
# Out:
# {'time': '2023-04-19T17:16:43.931000-04:00'}

# %%
qt.accounts
# Out:
# {'accounts': [{'type': 'Margin',
#    'number': '28588210',
#    'status': 'Active',
#    'isPrimary': True,
#    'isBilling': True,
#    'clientAccountType': 'Individual'}],
#  'userId': 1726369}

# %%
qt.account_positions(28588210)
# Out:
# {'positions': [{'symbol': 'MARA',
#    'symbolId': 34856789,
#    'openQuantity': -25,
#    'closedQuantity': 45,
#    'currentMarketValue': -266.25,
#    'currentPrice': 10.65,
#    'averageEntryPrice': 11.3726,
#    'dayPnl': 25.75,
#    'closedPnl': -139.77,
#    'openPnl': 18.065,
#    'totalCost': -284.315,
#    'isRealTime': True,
#    'isUnderReorg': False}]}

# %%
qt.account_balances(28588210)
# Out:
# {'perCurrencyBalances': [{'currency': 'CAD',
#    'cash': 100,
#    'marketValue': 0,
#    'totalEquity': 100,
#    'buyingPower': 333,
#    'maintenanceExcess': 100,
#    'isRealTime': True},
#   {'currency': 'USD',
#    'cash': 868.724743,
#    'marketValue': -266.5,
#    'totalEquity': 602.224743,
#    'buyingPower': -24.226606,
#    'maintenanceExcess': -7.275257,
#    'isRealTime': True}],
#  'combinedBalances': [{'currency': 'CAD',
#    'cash': 1263.135558,
#    'marketValue': -356.81685,
#    'totalEquity': 906.318708,
#    'buyingPower': 299.833165,
#    'maintenanceExcess': 90.039989,
#    'isRealTime': True},
#   {'currency': 'USD',
#    'cash': 943.41292,
#    'marketValue': -266.5,
#    'totalEquity': 676.91292,
#    'buyingPower': 219.012151,
#    'maintenanceExcess': 65.769415,
#    'isRealTime': True}],
#  'sodPerCurrencyBalances': [{'currency': 'CAD',
#    'cash': 100,
#    'marketValue': 0,
#    'totalEquity': 100,
#    'buyingPower': 333,
#    'maintenanceExcess': 100,
#    'isRealTime': True},
#   {'currency': 'USD',
#    'cash': 868.724743,
#    'marketValue': -292,
#    'totalEquity': 576.724743,
#    'buyingPower': -24.226606,
#    'maintenanceExcess': -7.275257,
#    'isRealTime': True}],
#  'sodCombinedBalances': [{'currency': 'CAD',
#    'cash': 1263.135558,
#    'marketValue': -390.9588,
#    'totalEquity': 872.176758,
#    'buyingPower': 299.833165,
#    'maintenanceExcess': 90.039989,
#    'isRealTime': True},
#   {'currency': 'USD',
#    'cash': 943.41292,
#    'marketValue': -292,
#    'totalEquity': 651.41292,
#    'buyingPower': 219.012151,
#    'maintenanceExcess': 65.769415,
#    'isRealTime': True}]}

# %%
def get_headers(url, method, api_key, api_secret, api_passphrase):
    now = int(time.time() * 1000)
    str_to_sign = str(now) + method + url
    signature = base64.b64encode(
        hmac.new(api_secret.encode('utf-8'), str_to_sign.encode('utf-8'), hashlib.sha256).digest())
    passphrase = base64.b64encode(
        hmac.new(api_secret.encode('utf-8'), api_passphrase.encode('utf-8'), hashlib.sha256).digest())
    headers = {
        "KC-API-SIGN": signature,
        "KC-API-TIMESTAMP": str(now),
        "KC-API-KEY": api_key,
        "KC-API-PASSPHRASE": passphrase,
        "KC-API-KEY-VERSION": "2"
    }
    return headers

# %%
def get_positions(account_number, api_key, api_secret, api_passphrase):
    url = f'https://api01.iq.questrade.com/v1/accounts/{account_number}/positions'
    headers = get_headers(url, 'GET', api_key, api_secret, api_passphrase)
    response = requests.get('https://api.kucoin.com' + url, headers=headers)
    if response.status_code == 200:
        balances = response.json()['data']
        return balances
    else:
        print('Failed to get account balances. Error code:', response.status_code)
        return None
    
    iABSmqIzECWi-RK9D56VUYo5CCWdFw
    l0velf5VNwO5hebjV0ggfGs9wgr6qOku0

# %%
{"access_token":"Azg4FK4HJ8tLi6IedtIsqLGqOcYhvEtu0","api_server":"https:\/\/api06.iq.questrade.com\/","expires_in":1800,"refresh_token":"mSUDSnmDVzee4Ci2sFWQd_SXROyFh6qh0","token_type":"Bearer"}

# %%
def get_orders(api_key, api_secret, api_passphrase):
    url = '/api/v1/orders'
    headers = get_headers(url, 'GET', api_key, api_secret, api_passphrase)
    response = requests.get('https://api.kucoin.com' + url, headers=headers)
    if response.status_code == 200:
        orders = response.json()['data']
        return orders
    else:
        print('Failed to get orders. Error code:', response.status_code)
        return None

# %%
# def get_headers(url):
#     now = int(time.time() * 1000)
#     str_to_sign = str(now) + 'GET' + url
#     signature = base64.b64encode(
#         hmac.new(api_secret.encode('utf-8'), str_to_sign.encode('utf-8'), hashlib.sha256).digest())
#     passphrase = base64.b64encode(
#         hmac.new(api_secret.encode('utf-8'), api_passphrase.encode('utf-8'), hashlib.sha256).digest())
#     headers = {
#         "KC-API-SIGN": signature,
#         "KC-API-TIMESTAMP": str(now),
#         "KC-API-KEY": api_key,
#         "KC-API-PASSPHRASE": passphrase,
#         "KC-API-KEY-VERSION": "2"
#     }
#     return headers

# def get_account_balance():
#     url = '/api/v1/accounts'
#     headers = get_headers(url, 'GET')
#     response = requests.get('https://api.kucoin.com' + url, headers=headers)
#     if response.status_code == 200:
#         balances = response.json()['data']
#         return balances
#     else:
#         print('Failed to get account balances. Error code:', response.status_code)
#         return None

# %%
def get_ticker(symbol):
    url = f'/api/v1/market/orderbook/level1?symbol={symbol}'
    headers = get_headers(url, 'GET')
    response = requests.get('https://api.kucoin.com' + url, headers=headers)
    if response.status_code == 200:
        ticker_data = response.json()
        return ticker_data['data']
    else:
        print('Failed to get ticker data for symbol', symbol, '. Error code:', response.status_code)
        return None

# %%
get_ticker('KNC-USDT')
# Out:
# {'time': 1681693515560,
#  'sequence': '165160496',
#  'price': '0.7784',
#  'size': '0.886',
#  'bestBid': '0.7767',
#  'bestBidSize': '150.6048',
#  'bestAsk': '0.7785',
#  'bestAskSize': '3853.6518'}

# %%
def get_all_tickers():
    url = '/api/v1/market/allTickers'
    headers = get_headers(url, 'GET')
    response = requests.get('https://api.kucoin.com' + url, headers=headers)
    if response.status_code == 200:
        ticker_data = json.loads(response.text)
        return ticker_data
    else:
        print('Failed to get ticker data. Error code:', response.status_code)
        return None

# %%
get_all_tickers()
# Out:
# {'code': '200000',
#  'data': {'time': 1681694531008,
#   'ticker': [{'symbol': 'NKN-USDT',
#     'symbolName': 'NKN-USDT',
#     'buy': '0.126217',
#     'sell': '0.126279',
#     'changeRate': '0.0026',
#     'changePrice': '0.000331',
#     'high': '0.130365',
#     'low': '0.124237',
#     'vol': '2107529.8296',
#     'volValue': '269275.8744732713',
#     'last': '0.126131',
#     'averagePrice': '0.12742076',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'LOOM-BTC',
#     'symbolName': 'LOOM-BTC',
#     'buy': '0.000002177',
#     'sell': '0.00000219',
#     'changeRate': '-0.0013',
#     'changePrice': '-0.000000003',
#     'high': '0.000002209',
#     'low': '0.00000215',
#     'vol': '72176.3174',
#     'volValue': '0.1567237238681',
#     'last': '0.000002177',
#     'averagePrice': '0.00000219',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'GEM-USDT',
#     'symbolName': 'GEM-USDT',
#     'buy': '0.00641',
#     'sell': '0.00643',
#     'changeRate': '0.0771',
#     'changePrice': '0.00046',
#     'high': '0.00655',
#     'low': '0.00591',
#     'vol': '6163721.5084',
#     'volValue': '38366.521986804',
#     'last': '0.00642',
#     'averagePrice': '0.00602536',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'CUSD-USDT',
#     'symbolName': 'CUSD-USDT',
#     'buy': '0.9945',
#     'sell': '0.9952',
#     'changeRate': '-0.0016',
#     'changePrice': '-0.0016',
#     'high': '0.9972',
#     'low': '0.9945',
#     'vol': '20142.9812',
#     'volValue': '20063.56579257',
#     'last': '0.9949',
#     'averagePrice': '0.99673917',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'LTC3L-USDT',
#     'symbolName': 'LTC3L-USDT',
#     'buy': '0.00221',
#     'sell': '0.002221',
#     'changeRate': '0.0973',
#     'changePrice': '0.000197',
#     'high': '0.002455',
#     'low': '0.002023',
#     'vol': '60799306.3599',
#     'volValue': '136659.2373933957',
#     'last': '0.00222',
#     'averagePrice': '0.00213577',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'OAS-USDT',
#     'symbolName': 'OAS-USDT',
#     'buy': '0.09331',
#     'sell': '0.0934',
#     'changeRate': '0.009',
#     'changePrice': '0.00084',
#     'high': '0.09434',
#     'low': '0.09264',
#     'vol': '550479.0126',
#     'volValue': '51164.191479242',
#     'last': '0.09348',
#     'averagePrice': '0.09300141',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'NEO-BTC',
#     'symbolName': 'NEO-BTC',
#     'buy': '0.0004471',
#     'sell': '0.0004482',
#     'changeRate': '0.0568',
#     'changePrice': '0.0000241',
#     'high': '0.0004678',
#     'low': '0.0004238',
#     'vol': '3937.798812',
#     'volValue': '1.7683427917582',
#     'last': '0.0004479',
#     'averagePrice': '0.00044392',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'KNC-USDT',
#     'symbolName': 'KNC-USDT',
#     'buy': '0.7805',
#     'sell': '0.7823',
#     'changeRate': '0.0073',
#     'changePrice': '0.0057',
#     'high': '0.8',
#     'low': '0.7732',
#     'vol': '31632.2468',
#     'volValue': '24865.39157198',
#     'last': '0.7802',
#     'averagePrice': '0.78368613',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'GRIN-BTC',
#     'symbolName': 'GRIN-BTC',
#     'buy': '0.000005754',
#     'sell': '0.000005879',
#     'changeRate': '0.095',
#     'changePrice': '0.000000503',
#     'high': '0.000006309',
#     'low': '0.000005263',
#     'vol': '1936.07428592',
#     'volValue': '0.01178461697051977',
#     'last': '0.000005796',
#     'averagePrice': '0.00000531',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'LYM-USDT',
#     'symbolName': 'LYM-USDT',
#     'buy': '0.002351',
#     'sell': '0.002352',
#     'changeRate': '-0.0175',
#     'changePrice': '-0.000042',
#     'high': '0.002404',
#     'low': '0.00235',
#     'vol': '44046656.53',
#     'volValue': '104276.2394549583',
#     'last': '0.002356',
#     'averagePrice': '0.00238127',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'NIM-ETH',
#     'symbolName': 'NIM-ETH',
#     'buy': '0.0000007834',
#     'sell': '0.0000007914',
#     'changeRate': '-0.0719',
#     'changePrice': '-0.0000000611',
#     'high': '0.0000008491',
#     'low': '0.0000007722',
#     'vol': '2694558.549',
#     'volValue': '2.1953744819897',
#     'last': '0.000000788',
#     'averagePrice': '0.00000082',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'SUTER-BTC',
#     'symbolName': 'SUTER-BTC',
#     'buy': '0.0000000209',
#     'sell': '0.000000021',
#     'changeRate': '0.0047',
#     'changePrice': '0.0000000001',
#     'high': '0.0000000213',
#     'low': '0.0000000203',
#     'vol': '443491.9357',
#     'volValue': '0.0092420561585',
#     'last': '0.000000021',
#     'averagePrice': '0.00000002',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'ID3S-USDT',
#     'symbolName': 'ID3S-USDT',
#     'buy': '0.5644',
#     'sell': '0.5761',
#     'changeRate': '-0.3516',
#     'changePrice': '-0.3061',
#     'high': '0.8893',
#     'low': '0.4255',
#     'vol': '623314.0768',
#     'volValue': '335568.95282475',
#     'last': '0.5644',
#     'averagePrice': '0.62448012',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'NULS-BTC',
#     'symbolName': 'NULS-BTC',
#     'buy': '0.00000957',
#     'sell': '0.00000965',
#     'changeRate': '0.0266',
#     'changePrice': '0.00000025',
#     'high': '0.00000999',
#     'low': '0.00000939',
#     'vol': '34680.203776',
#     'volValue': '0.33162755788448',
#     'last': '0.00000964',
#     'averagePrice': '0.00000949',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'HAI-USDT',
#     'symbolName': 'HAI-USDT',
#     'buy': '0.03726',
#     'sell': '0.03727',
#     'changeRate': '-0.0111',
#     'changePrice': '-0.00042',
#     'high': '0.03924',
#     'low': '0.03723',
#     'vol': '8213845.1829',
#     'volValue': '311582.217212921',
#     'last': '0.03734',
#     'averagePrice': '0.03783919',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'MITX-USDT',
#     'symbolName': 'MITX-USDT',
#     'buy': '0.013782',
#     'sell': '0.013821',
#     'changeRate': '0.0016',
#     'changePrice': '0.000023',
#     'high': '0.01422',
#     'low': '0.013593',
#     'vol': '11469517.1474',
#     'volValue': '159176.4950526704',
#     'last': '0.013824',
#     'averagePrice': '0.01382666',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'PDEX-USDT',
#     'symbolName': 'PDEX-USDT',
#     'buy': '1.5829',
#     'sell': '1.583',
#     'changeRate': '-0.0039',
#     'changePrice': '-0.0062',
#     'high': '1.6208',
#     'low': '1.5511',
#     'vol': '9430.6416',
#     'volValue': '14960.85570431',
#     'last': '1.583',
#     'averagePrice': '1.59084249',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '3',
#     'makerCoefficient': '3'},
#    {'symbol': 'HTR-BTC',
#     'symbolName': 'HTR-BTC',
#     'buy': '0.000003179',
#     'sell': '0.00000319',
#     'changeRate': '0.0747',
#     'changePrice': '0.000000221',
#     'high': '0.000003356',
#     'low': '0.000002919',
#     'vol': '262047.0688',
#     'volValue': '0.8305976307188',
#     'last': '0.000003179',
#     'averagePrice': '0.00000304',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'FLAME-USDT',
#     'symbolName': 'FLAME-USDT',
#     'buy': '0.04985',
#     'sell': '0.05025',
#     'changeRate': '-0.0111',
#     'changePrice': '-0.00056',
#     'high': '0.0511',
#     'low': '0.0495',
#     'vol': '235000.4562',
#     'volValue': '11827.177156533',
#     'last': '0.04985',
#     'averagePrice': '0.05065301',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'EPX-USDT',
#     'symbolName': 'EPX-USDT',
#     'buy': '0.000343',
#     'sell': '0.0003434',
#     'changeRate': '-0.0208',
#     'changePrice': '-0.0000073',
#     'high': '0.000354',
#     'low': '0.0003403',
#     'vol': '55438208.806',
#     'volValue': '19358.67003141398',
#     'last': '0.000343',
#     'averagePrice': '0.00034813',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'PUNDIX-BTC',
#     'symbolName': 'PUNDIX-BTC',
#     'buy': '0.00001671',
#     'sell': '0.00001697',
#     'changeRate': '0.0247',
#     'changePrice': '0.00000041',
#     'high': '0.00001712',
#     'low': '0.00001622',
#     'vol': '277.1356',
#     'volValue': '0.004632893801',
#     'last': '0.00001697',
#     'averagePrice': '0.00001659',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'AOG-USDT',
#     'symbolName': 'AOG-USDT',
#     'buy': '0.01442',
#     'sell': '0.01447',
#     'changeRate': '0.0419',
#     'changePrice': '0.00058',
#     'high': '0.01446',
#     'low': '0.01357',
#     'vol': '2412731.9695',
#     'volValue': '33677.901837792',
#     'last': '0.01442',
#     'averagePrice': '0.01381501',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'VET-BTC',
#     'symbolName': 'VET-BTC',
#     'buy': '0.000000858',
#     'sell': '0.000000859',
#     'changeRate': '0.0189',
#     'changePrice': '0.000000016',
#     'high': '0.000000875',
#     'low': '0.000000842',
#     'vol': '1713241.7102',
#     'volValue': '1.4762221278664',
#     'last': '0.00000086',
#     'averagePrice': '0.00000085',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'ATOM3L-USDT',
#     'symbolName': 'ATOM3L-USDT',
#     'buy': '0.00025194',
#     'sell': '0.00025317',
#     'changeRate': '0.0125',
#     'changePrice': '0.00000314',
#     'high': '0.00026578',
#     'low': '0.00023705',
#     'vol': '790949611.5487',
#     'volValue': '201077.187775711766',
#     'last': '0.00025296',
#     'averagePrice': '0.00024897',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'TWT-BTC',
#     'symbolName': 'TWT-BTC',
#     'buy': '0.0000415',
#     'sell': '0.00004163',
#     'changeRate': '0.0199',
#     'changePrice': '0.00000081',
#     'high': '0.00004182',
#     'low': '0.00004069',
#     'vol': '1606.3985',
#     'volValue': '0.066765048508',
#     'last': '0.0000415',
#     'averagePrice': '0.00004139',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'AGLD-USDT',
#     'symbolName': 'AGLD-USDT',
#     'buy': '0.5454',
#     'sell': '0.5474',
#     'changeRate': '-0.0256',
#     'changePrice': '-0.0144',
#     'high': '0.5636',
#     'low': '0.5376',
#     'vol': '79385.4024',
#     'volValue': '43732.31996567',
#     'last': '0.5462',
#     'averagePrice': '0.56250291',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'KAI-ETH',
#     'symbolName': 'KAI-ETH',
#     'buy': '0.00000261',
#     'sell': '0.000002625',
#     'changeRate': '-0.0034',
#     'changePrice': '-0.000000009',
#     'high': '0.00000276',
#     'low': '0.000002568',
#     'vol': '48363.9644',
#     'volValue': '0.1271586306448',
#     'last': '0.000002619',
#     'averagePrice': '0.00000259',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'YLD-USDT',
#     'symbolName': 'YLD-USDT',
#     'buy': '0.116622',
#     'sell': '0.117358',
#     'changeRate': '-0.0386',
#     'changePrice': '-0.004709',
#     'high': '0.124052',
#     'low': '0.115156',
#     'vol': '912882.5973',
#     'volValue': '109430.2124879319',
#     'last': '0.117072',
#     'averagePrice': '0.12184309',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'CPC-ETH',
#     'symbolName': 'CPC-ETH',
#     'buy': '0.000001505',
#     'sell': '0.000001519',
#     'changeRate': '-0.0097',
#     'changePrice': '-0.000000015',
#     'high': '0.000001538',
#     'low': '0.000001396',
#     'vol': '10347479.2377',
#     'volValue': '15.1318507970627',
#     'last': '0.000001518',
#     'averagePrice': '0.00000147',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'COTI-BTC',
#     'symbolName': 'COTI-BTC',
#     'buy': '0.000003043',
#     'sell': '0.000003055',
#     'changeRate': '0.0534',
#     'changePrice': '0.000000155',
#     'high': '0.000003217',
#     'low': '0.0000029',
#     'vol': '165546.2477',
#     'volValue': '0.5043578542187',
#     'last': '0.000003055',
#     'averagePrice': '0.00000301',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'CWS-USDT',
#     'symbolName': 'CWS-USDT',
#     'buy': '0.4402',
#     'sell': '0.4403',
#     'changeRate': '0.0408',
#     'changePrice': '0.0173',
#     'high': '0.458',
#     'low': '0.4213',
#     'vol': '260724.5024',
#     'volValue': '114489.25313927',
#     'last': '0.4403',
#     'averagePrice': '0.43089495',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'PEEL-BTC',
#     'symbolName': 'PEEL-BTC',
#     'buy': '0.000001601',
#     'sell': '0.000001675',
#     'changeRate': '-0.006',
#     'changePrice': '-0.00000001',
#     'high': '0.000001713',
#     'low': '0.000001623',
#     'vol': '1020.4023',
#     'volValue': '0.0016945746406',
#     'last': '0.000001632',
#     'averagePrice': '0.00000164',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'SENSO-USDT',
#     'symbolName': 'SENSO-USDT',
#     'buy': '0.107465',
#     'sell': '0.107785',
#     'changeRate': '-0.0338',
#     'changePrice': '-0.003773',
#     'high': '0.113328',
#     'low': '0.107',
#     'vol': '922317.8388',
#     'volValue': '101243.8226071118',
#     'last': '0.107763',
#     'averagePrice': '0.11058512',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'ALBT-USDT',
#     'symbolName': 'ALBT-USDT',
#     'buy': '0.06624',
#     'sell': '0',
#     'changeRate': '-0.393',
#     'changePrice': '-0.0429',
#     'high': '0.11212',
#     'low': '0.045',
#     'vol': '156110913.5263',
#     'volValue': '10701827.886108919',
#     'last': '0.06624',
#     'averagePrice': '0.1092395',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'ALICE-USDT',
#     'symbolName': 'ALICE-USDT',
#     'buy': '1.758',
#     'sell': '1.76',
#     'changeRate': '0.0103',
#     'changePrice': '0.018',
#     'high': '1.82',
#     'low': '1.734',
#     'vol': '36696.0015',
#     'volValue': '65307.8704839',
#     'last': '1.758',
#     'averagePrice': '1.76083498',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'UNIC-USDT',
#     'symbolName': 'UNIC-USDT',
#     'buy': '4.16',
#     'sell': '4.21',
#     'changeRate': '0.04',
#     'changePrice': '0.16',
#     'high': '4.23',
#     'low': '4',
#     'vol': '4220.916',
#     'volValue': '17409.404313',
#     'last': '4.16',
#     'averagePrice': '4.0994439',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'SYS-BTC',
#     'symbolName': 'SYS-BTC',
#     'buy': '0.000005753',
#     'sell': '0.000005791',
#     'changeRate': '0.0218',
#     'changePrice': '0.000000123',
#     'high': '0.000005844',
#     'low': '0.000005525',
#     'vol': '18253.2119',
#     'volValue': '0.1035745370815',
#     'last': '0.000005743',
#     'averagePrice': '0.00000565',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'IHC-USDT',
#     'symbolName': 'IHC-USDT',
#     'buy': '0.0000546',
#     'sell': '0.0000552',
#     'changeRate': '0.0054',
#     'changePrice': '0.0000003',
#     'high': '0.0000556',
#     'low': '0.0000538',
#     'vol': '627446963.8142',
#     'volValue': '34197.625324331',
#     'last': '0.0000549',
#     'averagePrice': '0.0000545',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'PNT-BTC',
#     'symbolName': 'PNT-BTC',
#     'buy': '0.00000714',
#     'sell': '0.000007343',
#     'changeRate': '-0.0128',
#     'changePrice': '-0.000000093',
#     'high': '0.000007448',
#     'low': '0.000007001',
#     'vol': '877.7724',
#     'volValue': '0.0064282745456',
#     'last': '0.00000717',
#     'averagePrice': '0.00000723',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'BULL-USDT',
#     'symbolName': 'BULL-USDT',
#     'buy': '0.003275',
#     'sell': '0.003276',
#     'changeRate': '-0.0423',
#     'changePrice': '-0.000145',
#     'high': '0.0035',
#     'low': '0.003076',
#     'vol': '27043650.4529',
#     'volValue': '88230.528375057',
#     'last': '0.003276',
#     'averagePrice': '0.0032136',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'STXDOWN-USDT',
#     'symbolName': 'STXDOWN-USDT',
#     'buy': '11.6991',
#     'sell': '11.9184',
#     'changeRate': '-0.0044',
#     'changePrice': '-0.0531',
#     'high': '12.1374',
#     'low': '10.3081',
#     'vol': '71.0243',
#     'volValue': '788.7535387',
#     'last': '11.7664',
#     'averagePrice': '11.30191365',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'BOSON-ETH',
#     'symbolName': 'BOSON-ETH',
#     'buy': '0.0001117',
#     'sell': '0.0001128',
#     'changeRate': '-0.0053',
#     'changePrice': '-0.0000006',
#     'high': '0.0001182',
#     'low': '0.0001096',
#     'vol': '7984.9855',
#     'volValue': '0.93216547638',
#     'last': '0.0001125',
#     'averagePrice': '0.00011208',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'ROOBEE-BTC',
#     'symbolName': 'ROOBEE-BTC',
#     'buy': '0.0000000323',
#     'sell': '0.0000000326',
#     'changeRate': '0.0618',
#     'changePrice': '0.0000000019',
#     'high': '0.0000000344',
#     'low': '0.0000000304',
#     'vol': '167629358.6834',
#     'volValue': '5.27805904803112',
#     'last': '0.0000000326',
#     'averagePrice': '0.00000003',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'SWASH-USDT',
#     'symbolName': 'SWASH-USDT',
#     'buy': '0.02087',
#     'sell': '0.02104',
#     'changeRate': '0.1306',
#     'changePrice': '0.00241',
#     'high': '0.0215',
#     'low': '0.01822',
#     'vol': '5823891.0341',
#     'volValue': '116456.289395642',
#     'last': '0.02085',
#     'averagePrice': '0.01927789',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'XEC-USDT',
#     'symbolName': 'XEC-USDT',
#     'buy': '0.00003198',
#     'sell': '0.00003203',
#     'changeRate': '0.0062',
#     'changePrice': '0.0000002',
#     'high': '0.00003268',
#     'low': '0.00003179',
#     'vol': '466019955.5402',
#     'volValue': '15026.373660581705',
#     'last': '0.00003199',
#     'averagePrice': '0.00003215',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'BCH-USDC',
#     'symbolName': 'BCH-USDC',
#     'buy': '132.64',
#     'sell': '132.76',
#     'changeRate': '0.005',
#     'changePrice': '0.66',
#     'high': '136',
#     'low': '131.41',
#     'vol': '17.059',
#     'volValue': '2298.702244',
#     'last': '132.07',
#     'averagePrice': '133.19491779',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'ATOM3S-USDT',
#     'symbolName': 'ATOM3S-USDT',
#     'buy': '0.002563',
#     'sell': '0.002595',
#     'changeRate': '-0.0359',
#     'changePrice': '-0.000096',
#     'high': '0.002761',
#     'low': '0.00245',
#     'vol': '29227722.1245',
#     'volValue': '74476.809793907',
#     'last': '0.002573',
#     'averagePrice': '0.00259685',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'CHSB-BTC',
#     'symbolName': 'CHSB-BTC',
#     'buy': '0.00000843',
#     'sell': '0.00000869',
#     'changeRate': '-0.1075',
#     'changePrice': '-0.000001',
#     'high': '0.00000934',
#     'low': '0.0000077',
#     'vol': '522666.2185',
#     'volValue': '4.45968497174',
#     'last': '0.0000083',
#     'averagePrice': '0.00000854',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'LINA-USDT',
#     'symbolName': 'LINA-USDT',
#     'buy': '0.014288',
#     'sell': '0.014298',
#     'changeRate': '0.0084',
#     'changePrice': '0.00012',
#     'high': '0.014775',
#     'low': '0.014033',
#     'vol': '55586908.3437',
#     'volValue': '800929.0994470381',
#     'last': '0.014316',
#     'averagePrice': '0.01431085',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'ETC-USDT',
#     'symbolName': 'ETC-USDT',
#     'buy': '21.8453',
#     'sell': '21.8559',
#     'changeRate': '-0.0043',
#     'changePrice': '-0.0959',
#     'high': '22.4716',
#     'low': '21.5438',
#     'vol': '30264.802632',
#     'volValue': '671436.195757908',
#     'last': '21.8578',
#     'averagePrice': '22.09301363',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'RUNE-USDT',
#     'symbolName': 'RUNE-USDT',
#     'buy': '1.645',
#     'sell': '1.6457',
#     'changeRate': '-0.0036',
#     'changePrice': '-0.006',
#     'high': '1.6922',
#     'low': '1.6316',
#     'vol': '396802.2185',
#     'volValue': '661382.42803936',
#     'last': '1.6467',
#     'averagePrice': '1.66658785',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'MPLX-USDT',
#     'symbolName': 'MPLX-USDT',
#     'buy': '0.03393',
#     'sell': '0.03462',
#     'changeRate': '-0.0476',
#     'changePrice': '-0.00172',
#     'high': '0.03636',
#     'low': '0.03365',
#     'vol': '104734.32',
#     'volValue': '3623.399743952',
#     'last': '0.03435',
#     'averagePrice': '0.03507653',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'TRAC-BTC',
#     'symbolName': 'TRAC-BTC',
#     'buy': '0.00001437',
#     'sell': '0.00001442',
#     'changeRate': '-0.0283',
#     'changePrice': '-0.00000042',
#     'high': '0.00001495',
#     'low': '0.00001379',
#     'vol': '293735.4235',
#     'volValue': '4.18635611622',
#     'last': '0.0000144',
#     'averagePrice': '0.00001465',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'HYDRA-USDT',
#     'symbolName': 'HYDRA-USDT',
#     'buy': '1.849',
#     'sell': '1.855',
#     'changeRate': '-0.0117',
#     'changePrice': '-0.022',
#     'high': '1.89',
#     'low': '1.841',
#     'vol': '9946.04791645',
#     'volValue': '18514.51508247795',
#     'last': '1.848',
#     'averagePrice': '1.86483309',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'ASTR-USDT',
#     'symbolName': 'ASTR-USDT',
#     'buy': '0.07203',
#     'sell': '0.07205',
#     'changeRate': '-0.0163',
#     'changePrice': '-0.0012',
#     'high': '0.07455',
#     'low': '0.07114',
#     'vol': '10678188.1945',
#     'volValue': '777328.990230101',
#     'last': '0.07205',
#     'averagePrice': '0.07356117',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'WBTC-ETH',
#     'symbolName': 'WBTC-ETH',
#     'buy': '14.2714',
#     'sell': '14.3558',
#     'changeRate': '-0.0101',
#     'changePrice': '-0.1464',
#     'high': '14.5621',
#     'low': '14.2002',
#     'vol': '0.4088',
#     'volValue': '5.86626366',
#     'last': '14.3403',
#     'averagePrice': '14.48507674',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'CSIX-ETH',
#     'symbolName': 'CSIX-ETH',
#     'buy': '0.000019939',
#     'sell': '0.000020109',
#     'changeRate': '-0.0478',
#     'changePrice': '-0.000001001',
#     'high': '0.000021656',
#     'low': '0.000019336',
#     'vol': '622815.6387',
#     'volValue': '12.6573346413441',
#     'last': '0.000019939',
#     'averagePrice': '0.00002071',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'BCH-USDT',
#     'symbolName': 'BCH-USDT',
#     'buy': '132.57',
#     'sell': '132.59',
#     'changeRate': '0.0091',
#     'changePrice': '1.2',
#     'high': '136.1',
#     'low': '131.3',
#     'vol': '2185.5094',
#     'volValue': '292730.788164',
#     'last': '132.64',
#     'averagePrice': '133.04343479',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'NGM-USDT',
#     'symbolName': 'NGM-USDT',
#     'buy': '0.02261',
#     'sell': '0.0229',
#     'changeRate': '-0.0087',
#     'changePrice': '-0.0002',
#     'high': '0.02337',
#     'low': '0.02141',
#     'vol': '354768.5077',
#     'volValue': '7915.184904573',
#     'last': '0.0227',
#     'averagePrice': '0.02244007',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'JAR-USDT',
#     'symbolName': 'JAR-USDT',
#     'buy': '0.003777',
#     'sell': '0.003794',
#     'changeRate': '0.0288',
#     'changePrice': '0.000106',
#     'high': '0.003989',
#     'low': '0.003656',
#     'vol': '12385516.6838',
#     'volValue': '46934.6688234406',
#     'last': '0.00378',
#     'averagePrice': '0.00367392',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'TONE-USDT',
#     'symbolName': 'TONE-USDT',
#     'buy': '0.01222',
#     'sell': '0.0123',
#     'changeRate': '-0.0072',
#     'changePrice': '-0.00009',
#     'high': '0.01263',
#     'low': '0.01212',
#     'vol': '820772.2829',
#     'volValue': '10202.358340444',
#     'last': '0.0123',
#     'averagePrice': '0.012468',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'POSI-USDT',
#     'symbolName': 'POSI-USDT',
#     'buy': '0.03906',
#     'sell': '0.03955',
#     'changeRate': '-0.0735',
#     'changePrice': '-0.00314',
#     'high': '0.04499',
#     'low': '0.03875',
#     'vol': '1196994.3241',
#     'volValue': '48843.585908297',
#     'last': '0.03956',
#     'averagePrice': '0.04118898',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'XDB-BTC',
#     'symbolName': 'XDB-BTC',
#     'buy': '0.0000000547',
#     'sell': '0.0000000549',
#     'changeRate': '0.0054',
#     'changePrice': '0.0000000003',
#     'high': '0.000000058',
#     'low': '0.0000000531',
#     'vol': '6281516.6275',
#     'volValue': '0.34797575339617',
#     'last': '0.0000000549',
#     'averagePrice': '0.00000005',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'EOS3L-USDT',
#     'symbolName': 'EOS3L-USDT',
#     'buy': '0.366569',
#     'sell': '0.370122',
#     'changeRate': '-0.0367',
#     'changePrice': '-0.014167',
#     'high': '0.402802',
#     'low': '0.35399',
#     'vol': '11520.3041',
#     'volValue': '4455.3284870639',
#     'last': '0.371119',
#     'averagePrice': '0.3931366',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'HYVE-BTC',
#     'symbolName': 'HYVE-BTC',
#     'buy': '0.000002',
#     'sell': '0.000002015',
#     'changeRate': '0.0494',
#     'changePrice': '0.000000095',
#     'high': '0.000002015',
#     'low': '0.000001868',
#     'vol': '3973.4581',
#     'volValue': '0.0077338914341',
#     'last': '0.000002015',
#     'averagePrice': '0.00000191',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'RUNE-USDC',
#     'symbolName': 'RUNE-USDC',
#     'buy': '1.6458',
#     'sell': '1.6498',
#     'changeRate': '0.0001',
#     'changePrice': '0.0002',
#     'high': '1.6904',
#     'low': '1.6339',
#     'vol': '3451.3373',
#     'volValue': '5773.32441307',
#     'last': '1.648',
#     'averagePrice': '1.66488263',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'ETC-USDC',
#     'symbolName': 'ETC-USDC',
#     'buy': '21.8508',
#     'sell': '21.8749',
#     'changeRate': '-0.0083',
#     'changePrice': '-0.1831',
#     'high': '22.4508',
#     'low': '21.5703',
#     'vol': '382.024355',
#     'volValue': '8438.5479941276',
#     'last': '21.8104',
#     'averagePrice': '22.08576644',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'KAVA-USDT',
#     'symbolName': 'KAVA-USDT',
#     'buy': '0.9338',
#     'sell': '0.9342',
#     'changeRate': '0.0203',
#     'changePrice': '0.0187',
#     'high': '0.9584',
#     'low': '0.8622',
#     'vol': '573898.2274',
#     'volValue': '540158.02159844',
#     'last': '0.9355',
#     'averagePrice': '0.94025464',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'GLQ-USDT',
#     'symbolName': 'GLQ-USDT',
#     'buy': '0.012703',
#     'sell': '0.012705',
#     'changeRate': '0.0888',
#     'changePrice': '0.001037',
#     'high': '0.014998',
#     'low': '0.01157',
#     'vol': '52250093.1044',
#     'volValue': '693916.9734116284',
#     'last': '0.012705',
#     'averagePrice': '0.01298015',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'SHX-BTC',
#     'symbolName': 'SHX-BTC',
#     'buy': '0.0000000186',
#     'sell': '0.0000000199',
#     'changeRate': '0.1179',
#     'changePrice': '0.0000000021',
#     'high': '0.0000000199',
#     'low': '0.0000000175',
#     'vol': '293909.2877',
#     'volValue': '0.00546327926404',
#     'last': '0.0000000199',
#     'averagePrice': '0.00000001',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'BDX-BTC',
#     'symbolName': 'BDX-BTC',
#     'buy': '0.000001932',
#     'sell': '0.000001958',
#     'changeRate': '0.0182',
#     'changePrice': '0.000000035',
#     'high': '0.000001958',
#     'low': '0.000001917',
#     'vol': '7021808.7488',
#     'volValue': '13.5393648901746',
#     'last': '0.000001958',
#     'averagePrice': '0.00000192',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'ETH-DAI',
#     'symbolName': 'ETH-DAI',
#     'buy': '2091.23',
#     'sell': '2098.48',
#     'changeRate': '-0.0027',
#     'changePrice': '-5.75',
#     'high': '2137',
#     'low': '2076.48',
#     'vol': '20.4164295',
#     'volValue': '43275.857307192',
#     'last': '2084.71',
#     'averagePrice': '2099.77528204',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'VSYS-USDT',
#     'symbolName': 'VSYS-USDT',
#     'buy': '0.001568',
#     'sell': '0.001579',
#     'changeRate': '0.022',
#     'changePrice': '0.000034',
#     'high': '0.001611',
#     'low': '0.001481',
#     'vol': '14706242.6128',
#     'volValue': '22869.4399293903',
#     'last': '0.001579',
#     'averagePrice': '0.00153298',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'REQ-BTC',
#     'symbolName': 'REQ-BTC',
#     'buy': '0.000003448',
#     'sell': '0.000003454',
#     'changeRate': '0.0034',
#     'changePrice': '0.000000012',
#     'high': '0.00000349',
#     'low': '0.000003425',
#     'vol': '58341.2705',
#     'volValue': '0.2006309737969',
#     'last': '0.000003444',
#     'averagePrice': '0.00000343',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'GOM2-BTC',
#     'symbolName': 'GOM2-BTC',
#     'buy': '0.0000001252',
#     'sell': '0.0000001274',
#     'changeRate': '0.0498',
#     'changePrice': '0.000000006',
#     'high': '0.0000001325',
#     'low': '0.0000001166',
#     'vol': '115122.5516',
#     'volValue': '0.01463360792616',
#     'last': '0.0000001264',
#     'averagePrice': '0.00000011',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'PIVX-BTC',
#     'symbolName': 'PIVX-BTC',
#     'buy': '0.000007663',
#     'sell': '0.00000782',
#     'changeRate': '-0.0408',
#     'changePrice': '-0.00000033',
#     'high': '0.00000847',
#     'low': '0.000003874',
#     'vol': '84579.74102',
#     'volValue': '0.65224659731259',
#     'last': '0.000007742',
#     'averagePrice': '0.00000809',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'RNDRDOWN-USDT',
#     'symbolName': 'RNDRDOWN-USDT',
#     'buy': '7.5182',
#     'sell': '7.6767',
#     'changeRate': '-0.1702',
#     'changePrice': '-1.5753',
#     'high': '9.252',
#     'low': '7.511',
#     'vol': '1857.9599',
#     'volValue': '15100.46527037',
#     'last': '7.6767',
#     'averagePrice': '8.32937579',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'GAS-USDT',
#     'symbolName': 'GAS-USDT',
#     'buy': '3.6566',
#     'sell': '3.6785',
#     'changeRate': '0.0505',
#     'changePrice': '0.1755',
#     'high': '3.8406',
#     'low': '3.4682',
#     'vol': '31575.821',
#     'volValue': '113443.59157815',
#     'last': '3.6501',
#     'averagePrice': '3.57098543',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'APT-USDT',
#     'symbolName': 'APT-USDT',
#     'buy': '12.4816',
#     'sell': '12.4837',
#     'changeRate': '0.0085',
#     'changePrice': '0.1062',
#     'high': '12.7407',
#     'low': '12.2148',
#     'vol': '187900.6423',
#     'volValue': '2344777.06501196',
#     'last': '12.4864',
#     'averagePrice': '12.52075253',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'TRX-USDT',
#     'symbolName': 'TRX-USDT',
#     'buy': '0.066227',
#     'sell': '0.066232',
#     'changeRate': '0.007',
#     'changePrice': '0.000463',
#     'high': '0.0667',
#     'low': '0.065735',
#     'vol': '32797619.3049',
#     'volValue': '2170787.3319596108',
#     'last': '0.066232',
#     'averagePrice': '0.06604306',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'CELO-USDT',
#     'symbolName': 'CELO-USDT',
#     'buy': '0.7162',
#     'sell': '0.7169',
#     'changeRate': '0.0115',
#     'changePrice': '0.0082',
#     'high': '0.7411',
#     'low': '0.7074',
#     'vol': '582163.635',
#     'volValue': '420899.49629339',
#     'last': '0.7175',
#     'averagePrice': '0.7182081',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'MOOV-USDT',
#     'symbolName': 'MOOV-USDT',
#     'buy': '0.007152',
#     'sell': '0.00717',
#     'changeRate': '-0.0177',
#     'changePrice': '-0.000129',
#     'high': '0.007501',
#     'low': '0.007152',
#     'vol': '4339752.043',
#     'volValue': '31760.1457680174',
#     'last': '0.007152',
#     'averagePrice': '0.00745473',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'NEO-KCS',
#     'symbolName': 'NEO-KCS',
#     'buy': '1.503',
#     'sell': '1.508',
#     'changeRate': '0.0407',
#     'changePrice': '0.059',
#     'high': '1.604',
#     'low': '1.449',
#     'vol': '9937.416061',
#     'volValue': '15237.21498509',
#     'last': '1.508',
#     'averagePrice': '1.53008247',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'ENJ-BTC',
#     'symbolName': 'ENJ-BTC',
#     'buy': '0.00001477',
#     'sell': '0.00001478',
#     'changeRate': '0.0186',
#     'changePrice': '0.00000027',
#     'high': '0.00001497',
#     'low': '0.00001449',
#     'vol': '10030.8637',
#     'volValue': '0.147674564232',
#     'last': '0.00001478',
#     'averagePrice': '0.00001458',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'VET-KCS',
#     'symbolName': 'VET-KCS',
#     'buy': '0.00288',
#     'sell': '0.002889',
#     'changeRate': '0.0045',
#     'changePrice': '0.000013',
#     'high': '0.002971',
#     'low': '0.002857',
#     'vol': '312766.5337',
#     'volValue': '911.9155811247',
#     'last': '0.002888',
#     'averagePrice': '0.00292254',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'SAND-USDT',
#     'symbolName': 'SAND-USDT',
#     'buy': '0.67966',
#     'sell': '0.67983',
#     'changeRate': '0.0107',
#     'changePrice': '0.00721',
#     'high': '0.69756',
#     'low': '0.67021',
#     'vol': '2660670.4233',
#     'volValue': '1815680.723517639',
#     'last': '0.68',
#     'averagePrice': '0.68036761',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'FIDA-USDT',
#     'symbolName': 'FIDA-USDT',
#     'buy': '0.4475',
#     'sell': '0.45',
#     'changeRate': '0.0209',
#     'changePrice': '0.0092',
#     'high': '0.4611',
#     'low': '0.4365',
#     'vol': '223218.6796',
#     'volValue': '99950.28368142',
#     'last': '0.4479',
#     'averagePrice': '0.44324716',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'HIFRIENDS-USDT',
#     'symbolName': 'HIFRIENDS-USDT',
#     'buy': '0.024296',
#     'sell': '0.024325',
#     'changeRate': '0.1094',
#     'changePrice': '0.002397',
#     'high': '0.025914',
#     'low': '0.021477',
#     'vol': '13176477.635',
#     'volValue': '309393.5119194288',
#     'last': '0.024302',
#     'averagePrice': '0.02273521',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '3',
#     'makerCoefficient': '3'},
#    {'symbol': 'KLAY-USDT',
#     'symbolName': 'KLAY-USDT',
#     'buy': '0.2552',
#     'sell': '0.2555',
#     'changeRate': '-0.0333',
#     'changePrice': '-0.0088',
#     'high': '0.2766',
#     'low': '0.2521',
#     'vol': '3003585.6249',
#     'volValue': '798971.82021424',
#     'last': '0.2554',
#     'averagePrice': '0.26646264',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'T-USDT',
#     'symbolName': 'T-USDT',
#     'buy': '0.03623',
#     'sell': '0.03629',
#     'changeRate': '0.0016',
#     'changePrice': '0.00006',
#     'high': '0.03707',
#     'low': '0.03588',
#     'vol': '1281849.1429',
#     'volValue': '46847.843682784',
#     'last': '0.03623',
#     'averagePrice': '0.03648611',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'SUN-USDT',
#     'symbolName': 'SUN-USDT',
#     'buy': '0.0062184',
#     'sell': '0.0062217',
#     'changeRate': '0.0128',
#     'changePrice': '0.000079',
#     'high': '0.0062402',
#     'low': '0.0061385',
#     'vol': '172263814.2635',
#     'volValue': '1067427.16555382487',
#     'last': '0.0062217',
#     'averagePrice': '0.00617683',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'PUSH-BTC',
#     'symbolName': 'PUSH-BTC',
#     'buy': '0.00001417',
#     'sell': '0.00001455',
#     'changeRate': '0.0161',
#     'changePrice': '0.00000023',
#     'high': '0.00001496',
#     'low': '0.00001366',
#     'vol': '2138.1512',
#     'volValue': '0.029866353049',
#     'last': '0.00001451',
#     'averagePrice': '0.00001398',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'PERP-BTC',
#     'symbolName': 'PERP-BTC',
#     'buy': '0.00002983',
#     'sell': '0.00003012',
#     'changeRate': '0.0625',
#     'changePrice': '0.00000175',
#     'high': '0.00003092',
#     'low': '0.00002781',
#     'vol': '1519.7278',
#     'volValue': '0.044819178942',
#     'last': '0.00002975',
#     'averagePrice': '0.00002901',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'DATA-USDT',
#     'symbolName': 'DATA-USDT',
#     'buy': '0.0401',
#     'sell': '0.04015',
#     'changeRate': '0.0111',
#     'changePrice': '0.00044',
#     'high': '0.04139',
#     'low': '0.03952',
#     'vol': '2014804.1334',
#     'volValue': '81536.634808221',
#     'last': '0.03996',
#     'averagePrice': '0.04019923',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'STORE-ETH',
#     'symbolName': 'STORE-ETH',
#     'buy': '0.00001724',
#     'sell': '0.00001738',
#     'changeRate': '-0.0197',
#     'changePrice': '-0.00000035',
#     'high': '0.00001796',
#     'low': '0.00001724',
#     'vol': '939347.7669',
#     'volValue': '16.531285471847',
#     'last': '0.00001735',
#     'averagePrice': '0.00001767',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'ID3L-USDT',
#     'symbolName': 'ID3L-USDT',
#     'buy': '42.9267',
#     'sell': '43.549',
#     'changeRate': '0.2724',
#     'changePrice': '9.2641',
#     'high': '57.0299',
#     'low': '33.6634',
#     'vol': '4617.3873',
#     'volValue': '218307.0439311',
#     'last': '43.2681',
#     'averagePrice': '42.7407383',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'ELF-ETH',
#     'symbolName': 'ELF-ETH',
#     'buy': '0.0001515',
#     'sell': '0.0001516',
#     'changeRate': '-0.0078',
#     'changePrice': '-0.0000012',
#     'high': '0.0001534',
#     'low': '0.0001509',
#     'vol': '18214.0737',
#     'volValue': '2.75738001701',
#     'last': '0.0001515',
#     'averagePrice': '0.00015211',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'NGL-BTC',
#     'symbolName': 'NGL-BTC',
#     'buy': '0.00000732',
#     'sell': '0.00000756',
#     'changeRate': '-0.0265',
#     'changePrice': '-0.0000002',
#     'high': '0.00000758',
#     'low': '0.00000732',
#     'vol': '122.831',
#     'volValue': '0.000923348602',
#     'last': '0.00000732',
#     'averagePrice': '0.00000748',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'KLAY-BTC',
#     'symbolName': 'KLAY-BTC',
#     'buy': '0.00000852',
#     'sell': '0.00000858',
#     'changeRate': '-0.0273',
#     'changePrice': '-0.00000024',
#     'high': '0.00000909',
#     'low': '0.00000841',
#     'vol': '4488.0133',
#     'volValue': '0.038672279971',
#     'last': '0.00000852',
#     'averagePrice': '0.0000088',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'CTC-BTC',
#     'symbolName': 'CTC-BTC',
#     'buy': '0.00001217',
#     'sell': '0.00001224',
#     'changeRate': '0.0124',
#     'changePrice': '0.00000015',
#     'high': '0.00001227',
#     'low': '0.00001203',
#     'vol': '13292.4099',
#     'volValue': '0.161756685718',
#     'last': '0.00001223',
#     'averagePrice': '0.0000121',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'LABS-USDT',
#     'symbolName': 'LABS-USDT',
#     'buy': '0.0019158',
#     'sell': '0.0019189',
#     'changeRate': '-0.1071',
#     'changePrice': '-0.0002304',
#     'high': '0.0022671',
#     'low': '0.0018903',
#     'vol': '527400621.9858',
#     'volValue': '1082273.76318288397',
#     'last': '0.0019189',
#     'averagePrice': '0.0020831',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'ETC-ETH',
#     'symbolName': 'ETC-ETH',
#     'buy': '0.010393',
#     'sell': '0.010451',
#     'changeRate': '-0.0162',
#     'changePrice': '-0.000172',
#     'high': '0.010584',
#     'low': '0.01039',
#     'vol': '639.106922',
#     'volValue': '6.749247421056',
#     'last': '0.01039',
#     'averagePrice': '0.01057784',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'BOND-USDT',
#     'symbolName': 'BOND-USDT',
#     'buy': '4.511',
#     'sell': '4.52',
#     'changeRate': '0.0157',
#     'changePrice': '0.07',
#     'high': '4.754',
#     'low': '4.446',
#     'vol': '13063.132',
#     'volValue': '60283.0159687',
#     'last': '4.516',
#     'averagePrice': '4.59072331',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'XMR-ETH',
#     'symbolName': 'XMR-ETH',
#     'buy': '0.07769',
#     'sell': '0.07776',
#     'changeRate': '0.0047',
#     'changePrice': '0.00037',
#     'high': '0.07903',
#     'low': '0.07629',
#     'vol': '23194.2726',
#     'volValue': '1804.434121342',
#     'last': '0.0779',
#     'averagePrice': '0.0777846',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'LTC3S-USDT',
#     'symbolName': 'LTC3S-USDT',
#     'buy': '0.011125',
#     'sell': '0.011224',
#     'changeRate': '-0.0934',
#     'changePrice': '-0.001163',
#     'high': '0.012484',
#     'low': '0.009966',
#     'vol': '7377396.9435',
#     'volValue': '80190.7977853095',
#     'last': '0.011279',
#     'averagePrice': '0.01180785',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'DPET-USDT',
#     'symbolName': 'DPET-USDT',
#     'buy': '0.06492',
#     'sell': '0.06518',
#     'changeRate': '0.0104',
#     'changePrice': '0.00067',
#     'high': '0.06586',
#     'low': '0.06415',
#     'vol': '304547.0439',
#     'volValue': '19747.685889677',
#     'last': '0.06507',
#     'averagePrice': '0.06475377',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'TARA-USDT',
#     'symbolName': 'TARA-USDT',
#     'buy': '0.0013361',
#     'sell': '0.0013424',
#     'changeRate': '-0.0842',
#     'changePrice': '-0.0001229',
#     'high': '0.0014935',
#     'low': '0.00124',
#     'vol': '164364134.8848',
#     'volValue': '234214.92935219862',
#     'last': '0.0013361',
#     'averagePrice': '0.0014597',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'DERO-USDT',
#     'symbolName': 'DERO-USDT',
# ...
#     'vol': '33827937566.1776',
#     'volValue': '390938.5967839457249',
#     'last': '0.000011383',
#     'averagePrice': '0.00001155',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'WOOP-USDT',
#     'symbolName': 'WOOP-USDT',
#     'buy': '0.0122',
#     'sell': '0.01221',
#     'changeRate': '0.0347',
#     'changePrice': '0.00041',
#     'high': '0.01228',
#     'low': '0.01175',
#     'vol': '12916010.6119',
#     'volValue': '155689.25402068',
#     'last': '0.0122',
#     'averagePrice': '0.01189127',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'STRONG-USDT',
#     'symbolName': 'STRONG-USDT',
#     'buy': '10.106',
#     'sell': '10.107',
#     'changeRate': '0.0906',
#     'changePrice': '0.84',
#     'high': '10.4',
#     'low': '9.244',
#     'vol': '5714.9636',
#     'volValue': '56399.6575582',
#     'last': '10.107',
#     'averagePrice': '9.7083943',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'ARPA-USDT',
#     'symbolName': 'ARPA-USDT',
#     'buy': '0.044167',
#     'sell': '0.044207',
#     'changeRate': '0.0051',
#     'changePrice': '0.000227',
#     'high': '0.0477',
#     'low': '0.04371',
#     'vol': '3057901.9279',
#     'volValue': '138858.6268674293',
#     'last': '0.04424',
#     'averagePrice': '0.04531599',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'CRPT-ETH',
#     'symbolName': 'CRPT-ETH',
#     'buy': '0.0000428',
#     'sell': '0.00004288',
#     'changeRate': '-0.0071',
#     'changePrice': '-0.00000031',
#     'high': '0.0000443',
#     'low': '0.00004161',
#     'vol': '34333.2133',
#     'volValue': '1.479992751424',
#     'last': '0.00004295',
#     'averagePrice': '0.00004244',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'CWAR-BTC',
#     'symbolName': 'CWAR-BTC',
#     'buy': '0.0000005',
#     'sell': '0.0000005299',
#     'changeRate': '0.0071',
#     'changePrice': '0.0000000036',
#     'high': '0.0000005272',
#     'low': '0.000000493',
#     'vol': '41460.0163',
#     'volValue': '0.02159838452846',
#     'last': '0.0000005099',
#     'averagePrice': '0.00000051',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '3',
#     'makerCoefficient': '3'},
#    {'symbol': 'OMG-ETH',
#     'symbolName': 'OMG-ETH',
#     'buy': '0.0006872',
#     'sell': '0.0006971',
#     'changeRate': '0.004',
#     'changePrice': '0.0000028',
#     'high': '0.0007',
#     'low': '0.0006843',
#     'vol': '422.7751',
#     'volValue': '0.29565535937',
#     'last': '0.000694',
#     'averagePrice': '0.00068864',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'FALCONS-USDT',
#     'symbolName': 'FALCONS-USDT',
#     'buy': '0.00404',
#     'sell': '0.004046',
#     'changeRate': '-0.0029',
#     'changePrice': '-0.000012',
#     'high': '0.004105',
#     'low': '0.004002',
#     'vol': '32611269.4025',
#     'volValue': '132019.8809136105',
#     'last': '0.004043',
#     'averagePrice': '0.00406538',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'THETA-USDT',
#     'symbolName': 'THETA-USDT',
#     'buy': '1.1108',
#     'sell': '1.1112',
#     'changeRate': '-0.0056',
#     'changePrice': '-0.0063',
#     'high': '1.175',
#     'low': '1.0931',
#     'vol': '746263.9618',
#     'volValue': '843600.80887495',
#     'last': '1.1114',
#     'averagePrice': '1.12624987',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'LITH-ETH',
#     'symbolName': 'LITH-ETH',
#     'buy': '0.0000004002',
#     'sell': '0.0000004159',
#     'changeRate': '0.011',
#     'changePrice': '0.0000000045',
#     'high': '0.00000041',
#     'low': '0.0000003884',
#     'vol': '237511.6564',
#     'volValue': '0.09440615276729',
#     'last': '0.00000041',
#     'averagePrice': '0.0000004',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '3',
#     'makerCoefficient': '3'},
#    {'symbol': 'HBAR-USDT',
#     'symbolName': 'HBAR-USDT',
#     'buy': '0.06784',
#     'sell': '0.06787',
#     'changeRate': '0.0096',
#     'changePrice': '0.00065',
#     'high': '0.06982',
#     'low': '0.06705',
#     'vol': '42194930.238',
#     'volValue': '2883850.014980228',
#     'last': '0.06789',
#     'averagePrice': '0.0678498',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'ETN-USDT',
#     'symbolName': 'ETN-USDT',
#     'buy': '0.0025',
#     'sell': '0.0025047',
#     'changeRate': '-0.0023',
#     'changePrice': '-0.0000059',
#     'high': '0.0026403',
#     'low': '0.0025',
#     'vol': '12060954.1804',
#     'volValue': '30714.08702667776',
#     'last': '0.0025047',
#     'averagePrice': '0.00251223',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'STARLY-USDT',
#     'symbolName': 'STARLY-USDT',
#     'buy': '0.01802',
#     'sell': '0.01822',
#     'changeRate': '-0.052',
#     'changePrice': '-0.00099',
#     'high': '0.01966',
#     'low': '0.01798',
#     'vol': '4711061.7352',
#     'volValue': '89217.282974603',
#     'last': '0.01803',
#     'averagePrice': '0.01878589',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'KDON-USDT',
#     'symbolName': 'KDON-USDT',
#     'buy': '0.01193',
#     'sell': '0.01204',
#     'changeRate': '-0.0237',
#     'changePrice': '-0.00029',
#     'high': '0.01228',
#     'low': '0.01193',
#     'vol': '774597.9545',
#     'volValue': '9357.668354576',
#     'last': '0.01193',
#     'averagePrice': '0.01217175',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'IGU-BTC',
#     'symbolName': 'IGU-BTC',
#     'buy': '0.000002197',
#     'sell': '0.000002237',
#     'changeRate': '-0.0111',
#     'changePrice': '-0.000000025',
#     'high': '0.000002262',
#     'low': '0.0000022',
#     'vol': '6659.9669',
#     'volValue': '0.0149556140372',
#     'last': '0.00000222',
#     'averagePrice': '0.00000225',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'OGN-BTC',
#     'symbolName': 'OGN-BTC',
#     'buy': '0.000004461',
#     'sell': '0.000004476',
#     'changeRate': '-0.0102',
#     'changePrice': '-0.000000046',
#     'high': '0.0000046',
#     'low': '0.000004414',
#     'vol': '23675.7523',
#     'volValue': '0.1063036831608',
#     'last': '0.000004446',
#     'averagePrice': '0.00000444',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'CPC-BTC',
#     'symbolName': 'CPC-BTC',
#     'buy': '0.0000001035',
#     'sell': '0.0000001061',
#     'changeRate': '-0.0037',
#     'changePrice': '-0.0000000004',
#     'high': '0.0000001064',
#     'low': '0.0000000958',
#     'vol': '9964122.6145',
#     'volValue': '1.00987446648918',
#     'last': '0.0000001055',
#     'averagePrice': '0.0000001',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'GTC-USDT',
#     'symbolName': 'GTC-USDT',
#     'buy': '1.9124',
#     'sell': '1.9143',
#     'changeRate': '0.0219',
#     'changePrice': '0.0412',
#     'high': '1.9429',
#     'low': '1.873',
#     'vol': '3470.1279',
#     'volValue': '6632.74835692',
#     'last': '1.9142',
#     'averagePrice': '1.90699946',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'XTM-USDT',
#     'symbolName': 'XTM-USDT',
#     'buy': '0.018846',
#     'sell': '0.019',
#     'changeRate': '0.0368',
#     'changePrice': '0.00067',
#     'high': '0.019898',
#     'low': '0.018153',
#     'vol': '4975297.4115',
#     'volValue': '93451.1702731927',
#     'last': '0.01885',
#     'averagePrice': '0.01847284',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'CELO-BTC',
#     'symbolName': 'CELO-BTC',
#     'buy': '0.00002388',
#     'sell': '0.00002395',
#     'changeRate': '0.0187',
#     'changePrice': '0.00000044',
#     'high': '0.00002448',
#     'low': '0.00002329',
#     'vol': '8146.3261',
#     'volValue': '0.193203288996',
#     'last': '0.00002395',
#     'averagePrice': '0.00002368',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'SUSHI-USDT',
#     'symbolName': 'SUSHI-USDT',
#     'buy': '1.17',
#     'sell': '1.1708',
#     'changeRate': '0.0048',
#     'changePrice': '0.0057',
#     'high': '1.2162',
#     'low': '1.1549',
#     'vol': '516348.3009',
#     'volValue': '615247.36961716',
#     'last': '1.1712',
#     'averagePrice': '1.18101754',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'TOKO-BTC',
#     'symbolName': 'TOKO-BTC',
#     'buy': '0.0000001011',
#     'sell': '0.0000001021',
#     'changeRate': '0.0912',
#     'changePrice': '0.0000000085',
#     'high': '0.0000001071',
#     'low': '0.0000000922',
#     'vol': '842521.9932',
#     'volValue': '0.08475833105309',
#     'last': '0.0000001016',
#     'averagePrice': '0.00000009',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'LINK-USDC',
#     'symbolName': 'LINK-USDC',
#     'buy': '7.9415',
#     'sell': '7.9489',
#     'changeRate': '-0.0026',
#     'changePrice': '-0.0214',
#     'high': '8.2',
#     'low': '7.8759',
#     'vol': '4139.4081',
#     'volValue': '33360.17046031',
#     'last': '7.9526',
#     'averagePrice': '8.02152867',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'SQUAD-USDT',
#     'symbolName': 'SQUAD-USDT',
#     'buy': '0.01702',
#     'sell': '0.01709',
#     'changeRate': '0.0011',
#     'changePrice': '0.00002',
#     'high': '0.01753',
#     'low': '0.01692',
#     'vol': '12812932.9944',
#     'volValue': '219897.213864218',
#     'last': '0.01711',
#     'averagePrice': '0.01693473',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'LTC-USDT',
#     'symbolName': 'LTC-USDT',
#     'buy': '98.776',
#     'sell': '98.777',
#     'changeRate': '0.0333',
#     'changePrice': '3.184',
#     'high': '102.117',
#     'low': '95.592',
#     'vol': '127670.17197966',
#     'volValue': '12675918.06324684044',
#     'last': '98.776',
#     'averagePrice': '97.70489151',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'OXT-ETH',
#     'symbolName': 'OXT-ETH',
#     'buy': '0.00004285',
#     'sell': '0.00004344',
#     'changeRate': '0.0195',
#     'changePrice': '0.00000084',
#     'high': '0.00004391',
#     'low': '0.00004278',
#     'vol': '360.4061',
#     'volValue': '0.015655682306',
#     'last': '0.00004391',
#     'averagePrice': '0.00004346',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'NULS-ETH',
#     'symbolName': 'NULS-ETH',
#     'buy': '0.0001373',
#     'sell': '0.00014',
#     'changeRate': '-0.005',
#     'changePrice': '-0.0000007',
#     'high': '0.0001415',
#     'low': '0.0001334',
#     'vol': '1891.115166',
#     'volValue': '0.2629852196351',
#     'last': '0.000138',
#     'averagePrice': '0.00013594',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'ANKR-BTC',
#     'symbolName': 'ANKR-BTC',
#     'buy': '0.000001209',
#     'sell': '0.0000012118',
#     'changeRate': '0.0122',
#     'changePrice': '0.0000000146',
#     'high': '0.0000012274',
#     'low': '0.0000011944',
#     'vol': '29800.7591',
#     'volValue': '0.03618925145458',
#     'last': '0.000001209',
#     'averagePrice': '0.00000122',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'CULT-USDT',
#     'symbolName': 'CULT-USDT',
#     'buy': '0.000005851',
#     'sell': '0.000005891',
#     'changeRate': '-0.0559',
#     'changePrice': '-0.000000349',
#     'high': '0.000006414',
#     'low': '0.000005671',
#     'vol': '17204028891.4317',
#     'volValue': '104816.2337580789192',
#     'last': '0.000005891',
#     'averagePrice': '0.00000628',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'FRONT-BTC',
#     'symbolName': 'FRONT-BTC',
#     'buy': '0.000008141',
#     'sell': '0.000008184',
#     'changeRate': '-0.0105',
#     'changePrice': '-0.000000087',
#     'high': '0.000008318',
#     'low': '0.00000814',
#     'vol': '36903.0736',
#     'volValue': '0.3032290340639',
#     'last': '0.000008142',
#     'averagePrice': '0.0000082',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'SCRT-USDT',
#     'symbolName': 'SCRT-USDT',
#     'buy': '0.7197',
#     'sell': '0.7227',
#     'changeRate': '0.0018',
#     'changePrice': '0.0013',
#     'high': '0.7483',
#     'low': '0.717',
#     'vol': '61003.371',
#     'volValue': '44653.34166246',
#     'last': '0.722',
#     'averagePrice': '0.72690555',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'TIME-USDT',
#     'symbolName': 'TIME-USDT',
#     'buy': '38.198',
#     'sell': '38.199',
#     'changeRate': '0.0068',
#     'changePrice': '0.259',
#     'high': '41.7',
#     'low': '37.931',
#     'vol': '5779.074',
#     'volValue': '229376.7519039',
#     'last': '38.199',
#     'averagePrice': '40.94195153',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'TLM-USDT',
#     'symbolName': 'TLM-USDT',
#     'buy': '0.02292',
#     'sell': '0.02298',
#     'changeRate': '-0.0099',
#     'changePrice': '-0.00023',
#     'high': '0.02425',
#     'low': '0.02256',
#     'vol': '6604536.3995',
#     'volValue': '154056.434075213',
#     'last': '0.02299',
#     'averagePrice': '0.02312559',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '1',
#     'makerCoefficient': '1'},
#    {'symbol': 'XCUR-USDT',
#     'symbolName': 'XCUR-USDT',
#     'buy': '0.04944',
#     'sell': '0.04994',
#     'changeRate': '-0.0247',
#     'changePrice': '-0.00126',
#     'high': '0.05178',
#     'low': '0.04901',
#     'vol': '1086023.0618',
#     'volValue': '54827.582033636',
#     'last': '0.04958',
#     'averagePrice': '0.05077447',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'CIRUS-ETH',
#     'symbolName': 'CIRUS-ETH',
#     'buy': '0.00003634',
#     'sell': '0.00003723',
#     'changeRate': '-0.0689',
#     'changePrice': '-0.0000027',
#     'high': '0.00003914',
#     'low': '0.0000359',
#     'vol': '20582.7267',
#     'volValue': '0.764039804806',
#     'last': '0.00003644',
#     'averagePrice': '0.00003784',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    {'symbol': 'CARR-BTC',
#     'symbolName': 'CARR-BTC',
#     'buy': '0.0000000497',
#     'sell': '0.0000000577',
#     'changeRate': '-0.0681',
#     'changePrice': '-0.000000004',
#     'high': '0.0000000611',
#     'low': '0.0000000531',
#     'vol': '3554600.0332',
#     'volValue': '0.20751542953348',
#     'last': '0.0000000547',
#     'averagePrice': '0.00000005',
#     'takerFeeRate': '0.001',
#     'makerFeeRate': '0.001',
#     'takerCoefficient': '2',
#     'makerCoefficient': '2'},
#    ...]}}

# %%
def get_symbols():
    url = '/api/v2/symbols'
    headers = get_headers(url, 'GET')
    response = requests.request('get', 'https://api.kucoin.com'+url, headers=headers)
    if response.status_code == 200:
        symbols_data = response.json()['data']
        symbols_df = pd.DataFrame(symbols_data)
        return symbols_df
    else:
        print('Failed to get symbols data. Error code:', response.status_code)
        return None

# %%
get_symbols()
# Out:
#              symbol           name baseCurrency quoteCurrency feeCurrency  \
# 0          LOKI-BTC       OXEN-BTC         LOKI           BTC         BTC
# 1          LOKI-ETH       OXEN-ETH         LOKI           ETH         ETH
# 2           NRG-BTC        NRG-BTC          NRG           BTC         BTC
# 3          AVA-USDT       AVA-USDT          AVA          USDT        USDT
# 4           FET-BTC        FET-BTC          FET           BTC         BTC
# ...             ...            ...          ...           ...         ...
# 1311  RNDRDOWN-USDT  RNDRDOWN-USDT     RNDRDOWN          USDT        USDT
# 1312     STXUP-USDT     STXUP-USDT        STXUP          USDT        USDT
# 1313   STXDOWN-USDT   STXDOWN-USDT      STXDOWN          USDT        USDT
# 1314    LINAUP-USDT    LINAUP-USDT       LINAUP          USDT        USDT
# 1315  LINADOWN-USDT  LINADOWN-USDT     LINADOWN          USDT        USDT
#
#      market baseMinSize quoteMinSize   baseMaxSize quoteMaxSize baseIncrement  \
# 0       BTC         0.1      0.00001   10000000000     99999999        0.0001
# 1      ALTS         0.1       0.0001   10000000000     99999999        0.0001
# 2       BTC        0.01      0.00001   10000000000     99999999        0.0001
# 3      USDS         0.1         0.01   10000000000     99999999        0.0001
# 4       BTC         0.1      0.00001   10000000000     99999999        0.0001
# ...     ...         ...          ...           ...          ...           ...
# 1311   USDS         0.1          0.1  999999999999         5000        0.0001
# 1312   USDS         0.1          0.1  999999999999         5000        0.0001
# 1313   USDS         0.1          0.1  999999999999         5000        0.0001
# 1314   USDS         0.1          0.1  999999999999         5000        0.0001
# 1315   USDS         0.1          0.1  999999999999         5000        0.0001
#
#      quoteIncrement priceIncrement priceLimitRate  minFunds  isMarginEnabled  \
# 0       0.000000001    0.000000001            0.1  0.000001            False
# 1         0.0000001      0.0000001            0.1   0.00001            False
# 2        0.00000001     0.00000001            0.1  0.000001            False
# 3          0.000001       0.000001            0.1       0.1            False
# 4       0.000000001    0.000000001            0.1  0.000001            False
# ...             ...            ...            ...       ...              ...
# 1311         0.0001         0.0001            0.1       0.1            False
# 1312         0.0001         0.0001            0.1       0.1            False
# 1313         0.0001         0.0001            0.1       0.1            False
# 1314         0.0001         0.0001            0.1       0.1            False
# 1315         0.0001         0.0001            0.1       0.1            False
#
#       enableTrading
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 1311           True
# 1312           True
# 1313           True
# 1314           True
# 1315           True
#
# [1316 rows x 17 columns]

# %%
def clean_symbols_data(symbols_df):
    symbols_df = symbols_df.loc[:, ['symbol', 'name', 'baseCurrency', 'quoteCurrency', 'feeCurrency', 'market']]
    symbols_df = symbols_df.rename(columns={
        'baseCurrency': 'base_currency',
        'quoteCurrency': 'quote_currency',
        'feeCurrency': 'fee_currency',
    })
    symbols_df = symbols_df.set_index('symbol')
    return symbols_df
symbols_df = get_symbols()
symbols_cleaned_df = clean_symbols_data(symbols_df)
symbols_cleaned_df.head()
symbols_cleaned_df.tail()
# Out:
#                         name base_currency quote_currency fee_currency market
# symbol
# RNDRDOWN-USDT  RNDRDOWN-USDT      RNDRDOWN           USDT         USDT   USDS
# STXUP-USDT        STXUP-USDT         STXUP           USDT         USDT   USDS
# STXDOWN-USDT    STXDOWN-USDT       STXDOWN           USDT         USDT   USDS
# LINAUP-USDT      LINAUP-USDT        LINAUP           USDT         USDT   USDS
# LINADOWN-USDT  LINADOWN-USDT      LINADOWN           USDT         USDT   USDS

# %%
def get_symbols_pair():
    symbols_df = get_symbols()
    return symbols_df['symbol']

# %%
get_symbols_pair()
# Out:
# 0            LOKI-BTC
# 1            LOKI-ETH
# 2             NRG-BTC
# 3            AVA-USDT
# 4             FET-BTC
#             ...
# 1311    RNDRDOWN-USDT
# 1312       STXUP-USDT
# 1313     STXDOWN-USDT
# 1314      LINAUP-USDT
# 1315    LINADOWN-USDT
# Name: symbol, Length: 1316, dtype: object

# %%
def get_base_currency():
    symbols_df = get_symbols()
    return symbols_df['baseCurrency']

# %%
get_base_currency()
# Out:
# 0           LOKI
# 1           LOKI
# 2            NRG
# 3            AVA
# 4            FET
#           ...
# 1311    RNDRDOWN
# 1312       STXUP
# 1313     STXDOWN
# 1314      LINAUP
# 1315    LINADOWN
# Name: baseCurrency, Length: 1316, dtype: object

# %%
def get_quote_currency():
    symbols_df = get_symbols()
    return symbols_df['quoteCurrency']

# %%
get_quote_currency()
# Out:
# 0        BTC
# 1        ETH
# 2        BTC
# 3       USDT
# 4        BTC
#         ...
# 1311    USDT
# 1312    USDT
# 1313    USDT
# 1314    USDT
# 1315    USDT
# Name: quoteCurrency, Length: 1316, dtype: object

# %%
def get_deposit_list(currency=None, page=None, pageSize=None):
    url = '/api/v1/deposits'
    headers = get_headers(url, 'GET')
    params = {}
    if currency:
        params['currency'] = currency
    if page:
        params['page'] = page
    if pageSize:
        params['pageSize'] = pageSize
    
    response = requests.get('https://api.kucoin.com' + url, headers=headers, params=params)
    if response.status_code == 200:
        deposit_list = response.json()
        return deposit_list
    else:
        print('Failed to get deposit list. Error code:', response.status_code)
        return None

# %%
get_deposit_list()
# Out:
# {'code': '200000',
#  'data': {'currentPage': 1,
#   'pageSize': 50,
#   'totalNum': 2,
#   'totalPage': 1,
#   'items': [{'currency': 'USDT',
#     'chain': 'eth',
#     'status': 'SUCCESS',
#     'address': '0x6771e5ff1bd0e575efa15464b12dc0956b4803ec',
#     'memo': '',
#     'isInner': False,
#     'amount': '1145.81000000',
#     'fee': '0.00000000',
#     'walletTxId': '0x5c3dd119172a19303d4dea59259a6a00d40e26b6a97c55986cde1ce616f555c4@1e998a0ab8a81db064bd0780da57c071',
#     'createdAt': 1656513999000,
#     'updatedAt': 1656514119000,
#     'remark': 'Deposit',
#     'arrears': False},
#    {'currency': 'USDT',
#     'chain': 'trx',
#     'status': 'SUCCESS',
#     'address': 'TZ88wBT8mZcD88q7o3dxuLYsvM7tfz21SU',
#     'memo': '',
#     'isInner': False,
#     'amount': '13078.45270000',
#     'fee': '0.00000000',
#     'walletTxId': 'fef93e1a0cc9998eb87530a0eadc6d2d22de2859ba2f6a928646b9277dc2a1c4@9f03b5d10da04073eb4fdf99e5ad0a12',
#     'createdAt': 1650040082000,
#     'updatedAt': 1650040082000,
#     'remark': 'Deposit',
#     'arrears': False}]}}

# %%
def get_base_fee():
    url = '/api/v1/base-fee'
    headers = get_headers(url, 'GET')
    response = requests.get('https://api.kucoin.com'+url, headers=headers)
    if response.status_code == 200:
        fees_data = response.json()['data']
        fees_df = pd.DataFrame(fees_data, index=[0])
        return fees_df
    else:
        print('Failed to get trade fees data. Error code:', response.status_code)
        return None

# %%
get_base_fee()
# Out:
#   takerFeeRate makerFeeRate
# 0        0.001        0.001

# %%
def get_actual_fee_rate(symbol):
    url = '/api/v1/trade-fees'
    headers = get_headers(url, 'GET')
    response = requests.get('https://api.kucoin.com'+url+'?symbols='+symbol, headers=headers)
    if response.status_code == 200:
        fees_data = response.json()['data']
        fees_df = pd.DataFrame(fees_data)
        return fees_df
    else:
        print('Failed to get actual fee rate data. Error code:', response.status_code)
        return None

# %%
get_actual_fee_rate('KNC-USDT')
# Out:
# Failed to get actual fee rate data. Error code: 401

# %%
def get_24hr_stats(symbol):
    url = 'https://api.kucoin.com/api/v1/market/stats'
    params = {'symbol': symbol}
    response = requests.get(url, params=params)
    data = json.loads(response.text)['data']
    return data

# %%
get_24hr_stats('KNC-USDT')
# Out:
# {'time': 1681693988563,
#  'symbol': 'KNC-USDT',
#  'buy': '0.7767',
#  'sell': '0.7784',
#  'changeRate': '0.0019',
#  'changePrice': '0.0015',
#  'high': '0.8',
#  'low': '0.7732',
#  'vol': '36100.905',
#  'volValue': '28329.13878927',
#  'last': '0.7767',
#  'averagePrice': '0.78368613',
#  'takerFeeRate': '0.001',
#  'makerFeeRate': '0.001',
#  'takerCoefficient': '1',
#  'makerCoefficient': '1'}

# %%
def get_market_list():
    endpoint = 'https://api.kucoin.com/api/v1/markets'
    response = requests.get(endpoint)
    data = json.loads(response.content)
    markets = data['data']
    print(markets)
    return markets

# %%
get_market_list()
# Out:
# ['USDS', 'Hong-Kong', 'BTC', 'KCS', 'ALTS', 'NFT-ETF', 'FIAT', 'Arbitrum', 'DeFi', 'Shanghai-Upgrade', 'NFT', 'AI', 'Polkadot', 'ETF', 'Layer 1']

# %%
def get_trade_histories(symbol):
    url = 'https://api.kucoin.com/api/v1/market/histories?symbol={}'.format(symbol)
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()['data']
    else:
        return None

# %%
#get_trade_histories('KNC-USDT')

# %%
def get_klines(symbol, interval, start_time=None, end_time=None, limit=None):
    url = f'https://api.kucoin.com/api/v1/market/candles?type={interval}&symbol={symbol}'
    if start_time:
        start_timestamp = int(pd.Timestamp(start_time).timestamp() * 1000)
        url += f'&startAt={start_timestamp}'
    if end_time:
        end_timestamp = int(pd.Timestamp(end_time).timestamp() * 1000)
        url += f'&endAt={end_timestamp}'
    if limit:
        url += f'&limit={limit}'
    response = requests.get(url)
    json_data = response.json()
    if 'data' not in json_data:
        print(f'No data found for {symbol} {interval} klines.')
        return None
    data = json_data['data']
    columns = ['time', 'open', 'close', 'high', 'low', 'volume']
    df = pd.DataFrame(data, columns=columns)
    df['time'] = pd.to_datetime(df['time'], unit='ms')
    return df

# %%
get_klines('KNC-USDT', '1day', '2022-04-16', '2022-07-25', limit=100)
# Out:
# Empty DataFrame
# Columns: [time, open, close, high, low, volume]
# Index: []

# %%
def get_currencies():
    url = '/api/v1/currencies'
    response = requests.get('https://api.kucoin.com' + url)
    if response.status_code == 200:
        currencies_data = response.json()
        return currencies_data
    else:
        print('Failed to get currencies data. Error code:', response.status_code)
        return None

# %%
def get_currencies2():
    url = '/api/v1/limit/orders'
    response = requests.get('https://api.kucoin.com' + url)
    if response.status_code == 200:
        currencies_data = response.json()
        return currencies_data
    else:
        print('Failed to get currencies data. Error code:', response.status_code)
        return None
    
get_currencies2()
# Out:
# Failed to get currencies data. Error code: 400

# %%
#get_currencies()

# %%
def get_fiat_price(symbol):
    url = 'https://api.kucoin.com/api/v1/prices'
    params = {"symbols": symbol}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()['data']
        return float(data[symbol])
    else:
        print(f"Failed to get {symbol} price. Error code:", response.status_code)
        return None

# %%
get_fiat_price('USDT')
# Out:
# 1.0005

# %%
def get_ohlc_data(symbol, interval='1day', columns=['timestamp', 'open', 'close', 'high', 'low', 'volume', 'turnover']):
    url = f'https://api.kucoin.com/api/v1/market/candles?symbol={symbol}&type={interval}'
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()['data']
        ohlc_data = []
        for candle in data:
            ohlc_data.append({
                columns[0]: candle[0],
                columns[1]: float(candle[1]),
                columns[2]: float(candle[4]),
                columns[3]: float(candle[2]),
                columns[4]: float(candle[3]),
                columns[5]: float(candle[5]),
                columns[6]: float(candle[6])
            })
        return ohlc_data
    else:
        print(f'Failed to get {symbol} OHLC data. Error code:', response.status_code)
        return None

# %%
#get_ohlc_data('KNC-USDT', '1day')

# %%
def get_investment_data(url='/api/v1/accounts'):
    headers = get_headers(url, 'GET')
    response = requests.get(f'https://api.kucoin.com{url}', headers=headers)
    if response.status_code == 200:
        data = response.json()
        return pd.DataFrame(data['data'])
    else:
        print(f"Failed to get investment data. Error code: {response.status_code}")
        return None

# %%
get_investment_data()
# Out:
#                          id currency   type     balance   available holds
# 0  625a8e24c3c51b0001e1a13a    ROUTE  trade   3729.2422   3729.2422     0
# 1  62d85e5b501cb3000163af50     ATOM  trade          50          50     0
# 2  62d854f9cf97b00001868262     API3  trade         235         235     0
# 3  62d8bdda975dca0001f55ac0      KNC  trade     142.316     142.316     0
# 4  6259aad5a560990001c98ddb     USDT  trade  0.00007904  0.00007904     0
# 5  62599d12c750d100018732c2     USDT   main           0           0     0

# %%
def get_total_portfolio_value():
    tickers = get_all_tickers()['data']['ticker']
    balances = get_account_balance()
    total_value = 0.0
    for row in balances:
        currency = row['currency']
        holdings = row['balance']
        ticker = next((item for item in tickers if item['symbol'] == f"{currency}-USDT"), None)
        if ticker is not None:
            price = float(ticker['last'])
            value = price * float(holdings)
            total_value += value
    return total_value

# %%
get_total_portfolio_value()
# Out:
# 10276.309091000001

# %%
def get_total_profit_loss():
    balances = get_account_balance()
    total_profit_loss = 0.0
    for balance in balances:
        currency = balance['currency']
        holdings = float(balance['balance'])
        if holdings == 0:
            continue
        ticker = next((item for item in get_all_tickers()['data']['ticker'] if item['symbol'] == f"{currency}-USDT"), None)
        if ticker:
            price = float(ticker.get('last', 0))
            avg_price = float(balance.get('avgPrice', 0))
            profit_loss = (price - avg_price) * holdings
            total_profit_loss += profit_loss
    return total_profit_loss

# %%
get_total_profit_loss()
# Out:
# 10297.371059800002
